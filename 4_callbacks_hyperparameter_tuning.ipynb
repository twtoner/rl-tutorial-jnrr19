# %% [markdown]
# <a href="https://colab.research.google.com/github/araffin/rl-tutorial-jnrr19/blob/sb3/4_callbacks_hyperparameter_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stable Baselines3 Tutorial - Callbacks and hyperparameter tuning
#
# Github repo: https://github.com/araffin/rl-tutorial-jnrr19/tree/sb3/
#
# Stable-Baselines3: https://github.com/DLR-RM/stable-baselines3
#
# Documentation: https://stable-baselines3.readthedocs.io/en/master/
#
# RL Baselines3 zoo: https://github.com/DLR-RM/rl-baselines3-zoo
#
#
# ## Introduction
#
# In this notebook, you will learn how to use [Callbacks](https://stable-baselines3.readthedocs.io/en/master/guide/callbacks.html) which allow to do monitoring, auto saving, model manipulation, progress bars, ...
#
#
# You will also see that finding good hyperparameters is key to success in RL.
#
# ## Install Dependencies and Stable Baselines3 Using Pip

# %%
# !apt install swig
# !pip install tqdm==4.36.1
# !pip install stable-baselines3[extra]
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# /home/twtoner/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.36ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/twtoner/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 2.1.2pop0-1587756471-20.04-cd2988e is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/twtoner/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.13.1-unknown is an invalid version and will not be supported in a future release
#   warnings.warn(
# Collecting tqdm==4.36.1
#   Downloading tqdm-4.36.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 492 kB/s eta 0:00:011
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
# Successfully installed tqdm-4.36.1
# /home/twtoner/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.36ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/twtoner/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 2.1.2pop0-1587756471-20.04-cd2988e is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/twtoner/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.13.1-unknown is an invalid version and will not be supported in a future release
#   warnings.warn(
# Requirement already satisfied: stable-baselines3[extra] in /home/twtoner/.local/lib/python3.8/site-packages (1.7.0)
# Requirement already satisfied: matplotlib in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: torch>=1.11 in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.11.0+cu113)
# Requirement already satisfied: gym==0.21 in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: cloudpickle in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: pandas in /usr/lib/python3/dist-packages (from stable-baselines3[extra]) (0.25.3)
# Requirement already satisfied: importlib-metadata~=4.13 in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: numpy in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.23.3)
# Requirement already satisfied: ale-py==0.7.4; extra == "extra" in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: rich; extra == "extra" in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (13.0.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2; extra == "extra" in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: pillow; extra == "extra" in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (9.2.0)
# Requirement already satisfied: opencv-python; extra == "extra" in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (4.7.0.68)
# Requirement already satisfied: tensorboard>=2.9.1; extra == "extra" in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.11.0)
# Requirement already satisfied: psutil; extra == "extra" in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm; extra == "extra" in /home/twtoner/.local/lib/python3.8/site-packages (from stable-baselines3[extra]) (4.36.1)
# Requirement already satisfied: packaging>=20.0 in /home/twtoner/.local/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib->stable-baselines3[extra]) (1.0.1)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib->stable-baselines3[extra]) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib->stable-baselines3[extra]) (2.4.6)
# Requirement already satisfied: fonttools>=4.22.0 in /home/twtoner/.local/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (4.32.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/twtoner/.local/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: typing-extensions in /home/twtoner/.local/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/twtoner/.local/lib/python3.8/site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.8.1)
# Requirement already satisfied: importlib-resources in /home/twtoner/.local/lib/python3.8/site-packages (from ale-py==0.7.4; extra == "extra"->stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/twtoner/.local/lib/python3.8/site-packages (from rich; extra == "extra"->stable-baselines3[extra]) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/twtoner/.local/lib/python3.8/site-packages (from rich; extra == "extra"->stable-baselines3[extra]) (2.11.2)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from autorom[accept-rom-license]~=0.4.2; extra == "extra"->stable-baselines3[extra]) (7.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from autorom[accept-rom-license]~=0.4.2; extra == "extra"->stable-baselines3[extra]) (2.22.0)
# Requirement already satisfied: AutoROM.accept-rom-license; extra == "accept-rom-license" in /home/twtoner/.local/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.4.2; extra == "extra"->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: grpcio>=1.24.3 in /home/twtoner/.local/lib/python3.8/site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (1.51.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/twtoner/.local/lib/python3.8/site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /home/twtoner/.local/lib/python3.8/site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (59.8.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/twtoner/.local/lib/python3.8/site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (0.34.2)
# Requirement already satisfied: absl-py>=0.4 in /home/twtoner/.local/lib/python3.8/site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/twtoner/.local/lib/python3.8/site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (2.16.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/twtoner/.local/lib/python3.8/site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /home/twtoner/.local/lib/python3.8/site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/twtoner/.local/lib/python3.8/site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/twtoner/.local/lib/python3.8/site-packages (from tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: six>=1.5 in /home/twtoner/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: libtorrent in /home/twtoner/.local/lib/python3.8/site-packages (from AutoROM.accept-rom-license; extra == "accept-rom-license"->autorom[accept-rom-license]~=0.4.2; extra == "extra"->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/twtoner/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/twtoner/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (5.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (0.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/twtoner/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/twtoner/.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/lib/python3/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3,>=1.6.3->tensorboard>=2.9.1; extra == "extra"->stable-baselines3[extra]) (0.4.2)

# %%
import gym
from stable_baselines3 import A2C, SAC, PPO, TD3

# %% [markdown]
# # The importance of hyperparameter tuning
#
# When compared with Supervised Learning, Deep Reinforcement Learning is far more sensitive to the choice of hyper-parameters such as learning rate, number of neurons, number of layers, optimizer ... etc.
# Poor choice of hyper-parameters can lead to poor/unstable convergence. This challenge is compounded by the variability in performance across random seeds (used to initialize the network weights and the environment).
#
# Here we demonstrate on a toy example the [Soft Actor Critic](https://arxiv.org/abs/1801.01290) algorithm applied in the Pendulum environment. Note the change in performance between the default and "tuned" parameters.

# %%
import numpy as np

from stable_baselines3.common.evaluation import evaluate_policy

# %%
eval_env = gym.make('Pendulum-v1')

# %%
default_model = SAC('MlpPolicy', 'Pendulum-v1', verbose=1, seed=0, batch_size=64, policy_kwargs=dict(net_arch=[64, 64])).learn(8000)
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.48e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 274       |
# |    time_elapsed    | 2         |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 20.9      |
# |    critic_loss     | 0.796     |
# |    ent_coef        | 0.814     |
# |    ent_coef_loss   | -0.336    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.61e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 255       |
# |    time_elapsed    | 6         |
# |    total_timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 46.3      |
# |    critic_loss     | 0.596     |
# |    ent_coef        | 0.644     |
# |    ent_coef_loss   | -0.652    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.57e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 252       |
# |    time_elapsed    | 9         |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 75.7      |
# |    critic_loss     | 0.891     |
# |    ent_coef        | 0.513     |
# |    ent_coef_loss   | -0.881    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.45e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 252       |
# |    time_elapsed    | 12        |
# |    total_timesteps | 3200      |
# | train/             |           |
# |    actor_loss      | 94.4      |
# |    critic_loss     | 1.47      |
# |    ent_coef        | 0.421     |
# |    ent_coef_loss   | -0.788    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.39e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 252       |
# |    time_elapsed    | 15        |
# |    total_timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 107       |
# |    critic_loss     | 9.49      |
# |    ent_coef        | 0.358     |
# |    ent_coef_loss   | -0.572    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3899      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.36e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 250       |
# |    time_elapsed    | 19        |
# |    total_timesteps | 4800      |
# | train/             |           |
# |    actor_loss      | 124       |
# |    critic_loss     | 5.86      |
# |    ent_coef        | 0.314     |
# |    ent_coef_loss   | -0.56     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 4699      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.34e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 248       |
# |    time_elapsed    | 22        |
# |    total_timesteps | 5600      |
# | train/             |           |
# |    actor_loss      | 136       |
# |    critic_loss     | 4.99      |
# |    ent_coef        | 0.284     |
# |    ent_coef_loss   | -0.0843   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 5499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.32e+03 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 248       |
# |    time_elapsed    | 25        |
# |    total_timesteps | 6400      |
# | train/             |           |
# |    actor_loss      | 143       |
# |    critic_loss     | 4.71      |
# |    ent_coef        | 0.24      |
# |    ent_coef_loss   | -0.36     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 6299      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -1.3e+03 |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 249      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 171      |
# |    critic_loss     | 4.22     |
# |    ent_coef        | 0.195    |
# |    ent_coef_loss   | -0.611   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.27e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 249       |
# |    time_elapsed    | 32        |
# |    total_timesteps | 8000      |
# | train/             |           |
# |    actor_loss      | 183       |
# |    critic_loss     | 2.43      |
# |    ent_coef        | 0.16      |
# |    ent_coef_loss   | -0.335    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7899      |
# ----------------------------------

# %%
mean_reward, std_reward = evaluate_policy(default_model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# /home/twtoner/.local/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:-873.37 +/- 46.56

# %%
tuned_model = SAC('MlpPolicy', 'Pendulum-v1', batch_size=256, verbose=1, policy_kwargs=dict(net_arch=[256, 256]), seed=0).learn(8000)
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.45e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 263       |
# |    time_elapsed    | 3         |
# |    total_timesteps | 800       |
# | train/             |           |
# |    actor_loss      | 24.7      |
# |    critic_loss     | 0.296     |
# |    ent_coef        | 0.813     |
# |    ent_coef_loss   | -0.331    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 699       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.56e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 239       |
# |    time_elapsed    | 6         |
# |    total_timesteps | 1600      |
# | train/             |           |
# |    actor_loss      | 53.1      |
# |    critic_loss     | 0.208     |
# |    ent_coef        | 0.644     |
# |    ent_coef_loss   | -0.649    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 1499      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.39e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 239       |
# |    time_elapsed    | 10        |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 69.7      |
# |    critic_loss     | 0.77      |
# |    ent_coef        | 0.526     |
# |    ent_coef_loss   | -0.66     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2299      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 235       |
# |    time_elapsed    | 13        |
# |    total_timesteps | 3200      |
# | train/             |           |
# |    actor_loss      | 74.2      |
# |    critic_loss     | 0.938     |
# |    ent_coef        | 0.45      |
# |    ent_coef_loss   | -0.605    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3099      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.01e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 236       |
# |    time_elapsed    | 16        |
# |    total_timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 72.2      |
# |    critic_loss     | 0.885     |
# |    ent_coef        | 0.389     |
# |    ent_coef_loss   | -0.326    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3899      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -883     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 236      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | 83.8     |
# |    critic_loss     | 1.52     |
# |    ent_coef        | 0.332    |
# |    ent_coef_loss   | -0.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -783     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 235      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | 71.5     |
# |    critic_loss     | 1.66     |
# |    ent_coef        | 0.275    |
# |    ent_coef_loss   | -0.763   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -715     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 236      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | 81.7     |
# |    critic_loss     | 1.61     |
# |    ent_coef        | 0.226    |
# |    ent_coef_loss   | -0.648   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -653     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 235      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 70.9     |
# |    critic_loss     | 1.79     |
# |    ent_coef        | 0.189    |
# |    ent_coef_loss   | -0.264   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -603     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 235      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 67.6     |
# |    critic_loss     | 2.03     |
# |    ent_coef        | 0.162    |
# |    ent_coef_loss   | -0.244   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------

# %%
mean_reward, std_reward = evaluate_policy(tuned_model, eval_env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-156.82 +/- 93.66

# %% [markdown]
# Exploring hyperparameter tuning is out of the scope (and time schedule) of this tutorial. However, you need to know that we provide tuned hyperparameter in the [rl zoo](https://github.com/DLR-RM/rl-baselines3-zoo) as well as automatic hyperparameter optimization using [Optuna](https://github.com/pfnet/optuna).

# %% [markdown]
# # Callbacks
#
#
# Please read the [documentation](https://stable-baselines3.readthedocs.io/en/master/guide/callbacks.html). Although Stable-Baselines3 provides you with a callback collection (e.g. for creating checkpoints or for evaluation), we are going to re-implement some so you can get a good understanding of how they work.
#
# To build a custom callback, you need to create a class that derives from `BaseCallback`. This will give you access to events (`_on_training_start`, `_on_step()`) and useful variables (like `self.model` for the RL model).
#
# `_on_step` returns a boolean value for whether or not the training should continue.
#
# Thanks to the access to the models variables, in particular `self.model`, we are able to even change the parameters of the model without halting the training, or changing the model's code.

# %%
from stable_baselines3.common.callbacks import BaseCallback

# %%
class CustomCallback(BaseCallback):
    """
    A custom callback that derives from ``BaseCallback``.

    :param verbose: (int) Verbosity level 0: not output 1: info 2: debug
    """
    def __init__(self, verbose=0):
        super(CustomCallback, self).__init__(verbose)
        # Those variables will be accessible in the callback
        # (they are defined in the base class)
        # The RL model
        # self.model = None  # type: BaseRLModel
        # An alias for self.model.get_env(), the environment used for training
        # self.training_env = None  # type: Union[gym.Env, VecEnv, None]
        # Number of time the callback was called
        # self.n_calls = 0  # type: int
        # self.num_timesteps = 0  # type: int
        # local and global variables
        # self.locals = None  # type: Dict[str, Any]
        # self.globals = None  # type: Dict[str, Any]
        # The logger object, used to report things in the terminal
        # self.logger = None  # type: logger.Logger
        # # Sometimes, for event callback, it is useful
        # # to have access to the parent object
        # self.parent = None  # type: Optional[BaseCallback]

    def _on_training_start(self) -> None:
        """
        This method is called before the first rollout starts.
        """
        pass

    def _on_rollout_start(self) -> None:
        """
        A rollout is the collection of environment interaction
        using the current policy.
        This event is triggered before collecting new samples.
        """
        pass

    def _on_step(self) -> bool:
        """
        This method will be called by the model after each call to `env.step()`.

        For child callback (of an `EventCallback`), this will be called
        when the event is triggered.

        :return: (bool) If the callback returns False, training is aborted early.
        """
        return True

    def _on_rollout_end(self) -> None:
        """
        This event is triggered before updating the policy.
        """
        pass

    def _on_training_end(self) -> None:
        """
        This event is triggered before exiting the `learn()` method.
        """
        pass

# %% [markdown]
# Here we have a simple callback that can only be called twice:

# %%
class SimpleCallback(BaseCallback):
    """
    a simple callback that can only be called twice

    :param verbose: (int) Verbosity level 0: not output 1: info 2: debug
    """
    def __init__(self, verbose=0):
        super(SimpleCallback, self).__init__(verbose)
        self._called = False
    
    def _on_step(self):
      if not self._called:
        print("callback - first call")
        self._called = True
        return True # returns True, training continues.
      print("callback - second call")
      return False # returns False, training stops.

# %%
model = SAC('MlpPolicy', 'Pendulum-v1', verbose=1)
model.learn(8000, callback=SimpleCallback())
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# callback - first call
# callback - second call

# %% [markdown]
# ## First example: Auto saving best model
# In RL, it is quite useful to keep a clean version of a model as you are training, as we can end up with burn-in of a bad policy. This is a typical use case for callback, as they can call the save function of the model, and observe the training over time.
#
# Using the monitoring wrapper, we can save statistics of the environment, and use them to determine the mean training reward.
# This allows us to save the best model while training.
#
# Note that this is not the proper way of evaluating an RL agent, you should create an test environment and evaluate the agent performance in the callback (cf `EvalCallback`). For simplicity, we will be using the training reward as a proxy.

# %%
import os

import numpy as np

from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.results_plotter import load_results, ts2xy

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq, log_dir, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print("Num timesteps: {}".format(self.num_timesteps))
                print("Best mean reward: {:.2f} - Last mean reward per episode: {:.2f}".format(self.best_mean_reward, mean_reward))

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print("Saving new best model at {} timesteps".format(x[-1]))
                    print("Saving new best model to {}.zip".format(self.save_path))
                  self.model.save(self.save_path)

        return True

# %%
# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env('CartPole-v1', n_envs=1, monitor_dir=log_dir)
# it is equivalent to:
# env = gym.make('CartPole-v1')
# env = Monitor(env, log_dir)
# env = DummyVecEnv([lambda: env])

# Create Callback
callback = SaveOnBestTrainingRewardCallback(check_freq=20, log_dir=log_dir, verbose=1)

model = A2C('MlpPolicy', env, verbose=0)
model.learn(total_timesteps=10000, callback=callback)
# Out:
# Num timesteps: 40
# Best mean reward: -inf - Last mean reward per episode: 16.00
# Saving new best model at 32 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 60
# Best mean reward: 16.00 - Last mean reward per episode: 13.75
# Num timesteps: 80
# Best mean reward: 16.00 - Last mean reward per episode: 13.33
# Num timesteps: 100
# Best mean reward: 16.00 - Last mean reward per episode: 13.33
# Num timesteps: 120
# Best mean reward: 16.00 - Last mean reward per episode: 13.33
# Num timesteps: 140
# Best mean reward: 16.00 - Last mean reward per episode: 17.00
# Saving new best model at 136 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 160
# Best mean reward: 17.00 - Last mean reward per episode: 17.00
# Num timesteps: 180
# Best mean reward: 17.00 - Last mean reward per episode: 17.00
# Num timesteps: 200
# Best mean reward: 17.00 - Last mean reward per episode: 19.00
# Saving new best model at 190 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 220
# Best mean reward: 19.00 - Last mean reward per episode: 19.18
# Saving new best model at 211 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 240
# Best mean reward: 19.18 - Last mean reward per episode: 19.18
# Num timesteps: 260
# Best mean reward: 19.18 - Last mean reward per episode: 20.17
# Saving new best model at 242 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 280
# Best mean reward: 20.17 - Last mean reward per episode: 20.62
# Saving new best model at 268 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 300
# Best mean reward: 20.62 - Last mean reward per episode: 20.43
# Num timesteps: 320
# Best mean reward: 20.62 - Last mean reward per episode: 20.40
# Num timesteps: 340
# Best mean reward: 20.62 - Last mean reward per episode: 19.65
# Num timesteps: 360
# Best mean reward: 20.62 - Last mean reward per episode: 19.94
# Num timesteps: 380
# Best mean reward: 20.62 - Last mean reward per episode: 19.94
# Num timesteps: 400
# Best mean reward: 20.62 - Last mean reward per episode: 19.94
# Num timesteps: 420
# Best mean reward: 20.62 - Last mean reward per episode: 21.11
# Saving new best model at 401 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 440
# Best mean reward: 21.11 - Last mean reward per episode: 21.11
# Num timesteps: 460
# Best mean reward: 21.11 - Last mean reward per episode: 21.48
# Saving new best model at 451 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 480
# Best mean reward: 21.48 - Last mean reward per episode: 21.23
# Num timesteps: 500
# Best mean reward: 21.48 - Last mean reward per episode: 20.79
# Num timesteps: 520
# Best mean reward: 21.48 - Last mean reward per episode: 20.48
# Num timesteps: 540
# Best mean reward: 21.48 - Last mean reward per episode: 20.48
# Num timesteps: 560
# Best mean reward: 21.48 - Last mean reward per episode: 20.70
# Num timesteps: 580
# Best mean reward: 21.48 - Last mean reward per episode: 20.61
# Num timesteps: 600
# Best mean reward: 21.48 - Last mean reward per episode: 20.62
# Num timesteps: 620
# Best mean reward: 21.48 - Last mean reward per episode: 20.62
# Num timesteps: 640
# Best mean reward: 21.48 - Last mean reward per episode: 20.65
# Num timesteps: 660
# Best mean reward: 21.48 - Last mean reward per episode: 20.47
# Num timesteps: 680
# Best mean reward: 21.48 - Last mean reward per episode: 20.21
# Num timesteps: 700
# Best mean reward: 21.48 - Last mean reward per episode: 20.21
# Num timesteps: 720
# Best mean reward: 21.48 - Last mean reward per episode: 20.62
# Num timesteps: 740
# Best mean reward: 21.48 - Last mean reward per episode: 20.62
# Num timesteps: 760
# Best mean reward: 21.48 - Last mean reward per episode: 21.29
# Num timesteps: 780
# Best mean reward: 21.48 - Last mean reward per episode: 21.29
# Num timesteps: 800
# Best mean reward: 21.48 - Last mean reward per episode: 21.69
# Saving new best model at 781 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 820
# Best mean reward: 21.69 - Last mean reward per episode: 21.95
# Saving new best model at 812 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 840
# Best mean reward: 21.95 - Last mean reward per episode: 21.79
# Num timesteps: 860
# Best mean reward: 21.95 - Last mean reward per episode: 21.92
# Num timesteps: 880
# Best mean reward: 21.95 - Last mean reward per episode: 21.92
# Num timesteps: 900
# Best mean reward: 21.95 - Last mean reward per episode: 21.92
# Num timesteps: 920
# Best mean reward: 21.95 - Last mean reward per episode: 21.92
# Num timesteps: 940
# Best mean reward: 21.95 - Last mean reward per episode: 23.50
# Saving new best model at 940 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 960
# Best mean reward: 23.50 - Last mean reward per episode: 23.41
# Num timesteps: 980
# Best mean reward: 23.50 - Last mean reward per episode: 23.41
# Num timesteps: 1000
# Best mean reward: 23.50 - Last mean reward per episode: 23.38
# Num timesteps: 1020
# Best mean reward: 23.50 - Last mean reward per episode: 23.40
# Num timesteps: 1040
# Best mean reward: 23.50 - Last mean reward per episode: 23.32
# Num timesteps: 1060
# Best mean reward: 23.50 - Last mean reward per episode: 23.32
# Num timesteps: 1080
# Best mean reward: 23.50 - Last mean reward per episode: 23.69
# Saving new best model at 1066 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 1100
# Best mean reward: 23.69 - Last mean reward per episode: 23.38
# Num timesteps: 1120
# Best mean reward: 23.69 - Last mean reward per episode: 23.19
# Num timesteps: 1140
# Best mean reward: 23.69 - Last mean reward per episode: 22.78
# Num timesteps: 1160
# Best mean reward: 23.69 - Last mean reward per episode: 22.65
# Num timesteps: 1180
# Best mean reward: 23.69 - Last mean reward per episode: 22.48
# Num timesteps: 1200
# Best mean reward: 23.69 - Last mean reward per episode: 22.30
# Num timesteps: 1220
# Best mean reward: 23.69 - Last mean reward per episode: 22.24
# Num timesteps: 1240
# Best mean reward: 23.69 - Last mean reward per episode: 22.22
# Num timesteps: 1260
# Best mean reward: 23.69 - Last mean reward per episode: 22.18
# Num timesteps: 1280
# Best mean reward: 23.69 - Last mean reward per episode: 22.32
# Num timesteps: 1300
# Best mean reward: 23.69 - Last mean reward per episode: 22.02
# Num timesteps: 1320
# Best mean reward: 23.69 - Last mean reward per episode: 21.87
# Num timesteps: 1340
# Best mean reward: 23.69 - Last mean reward per episode: 21.87
# Num timesteps: 1360
# Best mean reward: 23.69 - Last mean reward per episode: 21.87
# Num timesteps: 1380
# Best mean reward: 23.69 - Last mean reward per episode: 22.54
# Num timesteps: 1400
# Best mean reward: 23.69 - Last mean reward per episode: 22.54
# Num timesteps: 1420
# Best mean reward: 23.69 - Last mean reward per episode: 22.89
# Num timesteps: 1440
# Best mean reward: 23.69 - Last mean reward per episode: 22.89
# Num timesteps: 1460
# Best mean reward: 23.69 - Last mean reward per episode: 22.75
# Num timesteps: 1480
# Best mean reward: 23.69 - Last mean reward per episode: 22.69
# Num timesteps: 1500
# Best mean reward: 23.69 - Last mean reward per episode: 22.67
# Num timesteps: 1520
# Best mean reward: 23.69 - Last mean reward per episode: 22.60
# Num timesteps: 1540
# Best mean reward: 23.69 - Last mean reward per episode: 22.53
# Num timesteps: 1560
# Best mean reward: 23.69 - Last mean reward per episode: 22.43
# Num timesteps: 1580
# Best mean reward: 23.69 - Last mean reward per episode: 22.44
# Num timesteps: 1600
# Best mean reward: 23.69 - Last mean reward per episode: 22.44
# Num timesteps: 1620
# Best mean reward: 23.69 - Last mean reward per episode: 22.61
# Num timesteps: 1640
# Best mean reward: 23.69 - Last mean reward per episode: 22.61
# Num timesteps: 1660
# Best mean reward: 23.69 - Last mean reward per episode: 22.61
# Num timesteps: 1680
# Best mean reward: 23.69 - Last mean reward per episode: 23.21
# Num timesteps: 1700
# Best mean reward: 23.69 - Last mean reward per episode: 23.21
# Num timesteps: 1720
# Best mean reward: 23.69 - Last mean reward per episode: 23.37
# Num timesteps: 1740
# Best mean reward: 23.69 - Last mean reward per episode: 23.37
# Num timesteps: 1760
# Best mean reward: 23.69 - Last mean reward per episode: 23.65
# Num timesteps: 1780
# Best mean reward: 23.69 - Last mean reward per episode: 23.65
# Num timesteps: 1800
# Best mean reward: 23.69 - Last mean reward per episode: 23.65
# Num timesteps: 1820
# Best mean reward: 23.69 - Last mean reward per episode: 24.04
# Saving new best model at 1803 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 1840
# Best mean reward: 24.04 - Last mean reward per episode: 24.20
# Saving new best model at 1839 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 1860
# Best mean reward: 24.20 - Last mean reward per episode: 24.10
# Num timesteps: 1880
# Best mean reward: 24.20 - Last mean reward per episode: 24.10
# Num timesteps: 1900
# Best mean reward: 24.20 - Last mean reward per episode: 24.10
# Num timesteps: 1920
# Best mean reward: 24.20 - Last mean reward per episode: 24.37
# Saving new best model at 1901 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 1940
# Best mean reward: 24.37 - Last mean reward per episode: 24.37
# Num timesteps: 1960
# Best mean reward: 24.37 - Last mean reward per episode: 24.37
# Num timesteps: 1980
# Best mean reward: 24.37 - Last mean reward per episode: 24.37
# Num timesteps: 2000
# Best mean reward: 24.37 - Last mean reward per episode: 25.24
# Saving new best model at 1994 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2020
# Best mean reward: 25.24 - Last mean reward per episode: 25.12
# Num timesteps: 2040
# Best mean reward: 25.24 - Last mean reward per episode: 25.12
# Num timesteps: 2060
# Best mean reward: 25.24 - Last mean reward per episode: 25.12
# Num timesteps: 2080
# Best mean reward: 25.24 - Last mean reward per episode: 25.12
# Num timesteps: 2100
# Best mean reward: 25.24 - Last mean reward per episode: 25.12
# Num timesteps: 2120
# Best mean reward: 25.24 - Last mean reward per episode: 25.12
# Num timesteps: 2140
# Best mean reward: 25.24 - Last mean reward per episode: 26.42
# Saving new best model at 2140 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2160
# Best mean reward: 26.42 - Last mean reward per episode: 26.42
# Num timesteps: 2180
# Best mean reward: 26.42 - Last mean reward per episode: 26.41
# Num timesteps: 2200
# Best mean reward: 26.42 - Last mean reward per episode: 26.41
# Num timesteps: 2220
# Best mean reward: 26.42 - Last mean reward per episode: 26.41
# Num timesteps: 2240
# Best mean reward: 26.42 - Last mean reward per episode: 26.41
# Num timesteps: 2260
# Best mean reward: 26.42 - Last mean reward per episode: 27.23
# Saving new best model at 2260 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2280
# Best mean reward: 27.23 - Last mean reward per episode: 27.23
# Num timesteps: 2300
# Best mean reward: 27.23 - Last mean reward per episode: 27.23
# Num timesteps: 2320
# Best mean reward: 27.23 - Last mean reward per episode: 27.23
# Num timesteps: 2340
# Best mean reward: 27.23 - Last mean reward per episode: 27.71
# Saving new best model at 2328 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2360
# Best mean reward: 27.71 - Last mean reward per episode: 27.62
# Num timesteps: 2380
# Best mean reward: 27.71 - Last mean reward per episode: 27.67
# Num timesteps: 2400
# Best mean reward: 27.71 - Last mean reward per episode: 27.67
# Num timesteps: 2420
# Best mean reward: 27.71 - Last mean reward per episode: 27.67
# Num timesteps: 2440
# Best mean reward: 27.71 - Last mean reward per episode: 27.67
# Num timesteps: 2460
# Best mean reward: 27.71 - Last mean reward per episode: 28.20
# Saving new best model at 2453 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2480
# Best mean reward: 28.20 - Last mean reward per episode: 28.20
# Num timesteps: 2500
# Best mean reward: 28.20 - Last mean reward per episode: 28.20
# Num timesteps: 2520
# Best mean reward: 28.20 - Last mean reward per episode: 28.20
# Num timesteps: 2540
# Best mean reward: 28.20 - Last mean reward per episode: 28.20
# Num timesteps: 2560
# Best mean reward: 28.20 - Last mean reward per episode: 28.99
# Saving new best model at 2551 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2580
# Best mean reward: 28.99 - Last mean reward per episode: 28.83
# Num timesteps: 2600
# Best mean reward: 28.99 - Last mean reward per episode: 28.53
# Num timesteps: 2620
# Best mean reward: 28.99 - Last mean reward per episode: 28.53
# Num timesteps: 2640
# Best mean reward: 28.99 - Last mean reward per episode: 28.53
# Num timesteps: 2660
# Best mean reward: 28.99 - Last mean reward per episode: 28.85
# Num timesteps: 2680
# Best mean reward: 28.99 - Last mean reward per episode: 28.85
# Num timesteps: 2700
# Best mean reward: 28.99 - Last mean reward per episode: 28.85
# Num timesteps: 2720
# Best mean reward: 28.99 - Last mean reward per episode: 29.16
# Saving new best model at 2712 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2740
# Best mean reward: 29.16 - Last mean reward per episode: 28.98
# Num timesteps: 2760
# Best mean reward: 29.16 - Last mean reward per episode: 28.93
# Num timesteps: 2780
# Best mean reward: 29.16 - Last mean reward per episode: 28.85
# Num timesteps: 2800
# Best mean reward: 29.16 - Last mean reward per episode: 28.85
# Num timesteps: 2820
# Best mean reward: 29.16 - Last mean reward per episode: 28.85
# Num timesteps: 2840
# Best mean reward: 29.16 - Last mean reward per episode: 28.85
# Num timesteps: 2860
# Best mean reward: 29.16 - Last mean reward per episode: 28.85
# Num timesteps: 2880
# Best mean reward: 29.16 - Last mean reward per episode: 29.52
# Saving new best model at 2863 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2900
# Best mean reward: 29.52 - Last mean reward per episode: 29.52
# Num timesteps: 2920
# Best mean reward: 29.52 - Last mean reward per episode: 29.62
# Saving new best model at 2903 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2940
# Best mean reward: 29.62 - Last mean reward per episode: 29.67
# Saving new best model at 2937 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2960
# Best mean reward: 29.67 - Last mean reward per episode: 29.51
# Num timesteps: 2980
# Best mean reward: 29.67 - Last mean reward per episode: 29.51
# Num timesteps: 3000
# Best mean reward: 29.67 - Last mean reward per episode: 29.59
# Num timesteps: 3020
# Best mean reward: 29.67 - Last mean reward per episode: 29.59
# Num timesteps: 3040
# Best mean reward: 29.67 - Last mean reward per episode: 29.59
# Num timesteps: 3060
# Best mean reward: 29.67 - Last mean reward per episode: 29.59
# Num timesteps: 3080
# Best mean reward: 29.67 - Last mean reward per episode: 30.42
# Saving new best model at 3074 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3100
# Best mean reward: 30.42 - Last mean reward per episode: 30.42
# Num timesteps: 3120
# Best mean reward: 30.42 - Last mean reward per episode: 30.42
# Num timesteps: 3140
# Best mean reward: 30.42 - Last mean reward per episode: 30.42
# Num timesteps: 3160
# Best mean reward: 30.42 - Last mean reward per episode: 31.05
# Saving new best model at 3147 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3180
# Best mean reward: 31.05 - Last mean reward per episode: 31.05
# Num timesteps: 3200
# Best mean reward: 31.05 - Last mean reward per episode: 31.05
# Num timesteps: 3220
# Best mean reward: 31.05 - Last mean reward per episode: 31.61
# Saving new best model at 3216 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3240
# Best mean reward: 31.61 - Last mean reward per episode: 31.61
# Num timesteps: 3260
# Best mean reward: 31.61 - Last mean reward per episode: 31.61
# Num timesteps: 3280
# Best mean reward: 31.61 - Last mean reward per episode: 31.61
# Num timesteps: 3300
# Best mean reward: 31.61 - Last mean reward per episode: 31.61
# Num timesteps: 3320
# Best mean reward: 31.61 - Last mean reward per episode: 32.48
# Saving new best model at 3314 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3340
# Best mean reward: 32.48 - Last mean reward per episode: 32.48
# Num timesteps: 3360
# Best mean reward: 32.48 - Last mean reward per episode: 32.64
# Saving new best model at 3344 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3380
# Best mean reward: 32.64 - Last mean reward per episode: 32.47
# Num timesteps: 3400
# Best mean reward: 32.64 - Last mean reward per episode: 32.47
# Num timesteps: 3420
# Best mean reward: 32.64 - Last mean reward per episode: 32.47
# Num timesteps: 3440
# Best mean reward: 32.64 - Last mean reward per episode: 32.86
# Saving new best model at 3422 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3460
# Best mean reward: 32.86 - Last mean reward per episode: 32.86
# Num timesteps: 3480
# Best mean reward: 32.86 - Last mean reward per episode: 32.86
# Num timesteps: 3500
# Best mean reward: 32.86 - Last mean reward per episode: 33.44
# Saving new best model at 3497 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3520
# Best mean reward: 33.44 - Last mean reward per episode: 33.44
# Num timesteps: 3540
# Best mean reward: 33.44 - Last mean reward per episode: 33.44
# Num timesteps: 3560
# Best mean reward: 33.44 - Last mean reward per episode: 33.44
# Num timesteps: 3580
# Best mean reward: 33.44 - Last mean reward per episode: 33.90
# Saving new best model at 3580 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3600
# Best mean reward: 33.90 - Last mean reward per episode: 33.90
# Num timesteps: 3620
# Best mean reward: 33.90 - Last mean reward per episode: 33.95
# Saving new best model at 3606 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3640
# Best mean reward: 33.95 - Last mean reward per episode: 33.95
# Num timesteps: 3660
# Best mean reward: 33.95 - Last mean reward per episode: 33.95
# Num timesteps: 3680
# Best mean reward: 33.95 - Last mean reward per episode: 33.95
# Num timesteps: 3700
# Best mean reward: 33.95 - Last mean reward per episode: 34.49
# Saving new best model at 3691 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3720
# Best mean reward: 34.49 - Last mean reward per episode: 34.49
# Num timesteps: 3740
# Best mean reward: 34.49 - Last mean reward per episode: 34.49
# Num timesteps: 3760
# Best mean reward: 34.49 - Last mean reward per episode: 34.49
# Num timesteps: 3780
# Best mean reward: 34.49 - Last mean reward per episode: 34.49
# Num timesteps: 3800
# Best mean reward: 34.49 - Last mean reward per episode: 34.49
# Num timesteps: 3820
# Best mean reward: 34.49 - Last mean reward per episode: 34.49
# Num timesteps: 3840
# Best mean reward: 34.49 - Last mean reward per episode: 34.49
# Num timesteps: 3860
# Best mean reward: 34.49 - Last mean reward per episode: 34.49
# Num timesteps: 3880
# Best mean reward: 34.49 - Last mean reward per episode: 35.93
# Saving new best model at 3861 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3900
# Best mean reward: 35.93 - Last mean reward per episode: 36.11
# Saving new best model at 3897 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3920
# Best mean reward: 36.11 - Last mean reward per episode: 36.11
# Num timesteps: 3940
# Best mean reward: 36.11 - Last mean reward per episode: 36.11
# Num timesteps: 3960
# Best mean reward: 36.11 - Last mean reward per episode: 36.11
# Num timesteps: 3980
# Best mean reward: 36.11 - Last mean reward per episode: 36.11
# Num timesteps: 4000
# Best mean reward: 36.11 - Last mean reward per episode: 36.11
# Num timesteps: 4020
# Best mean reward: 36.11 - Last mean reward per episode: 36.11
# Num timesteps: 4040
# Best mean reward: 36.11 - Last mean reward per episode: 36.11
# Num timesteps: 4060
# Best mean reward: 36.11 - Last mean reward per episode: 37.41
# Saving new best model at 4047 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4080
# Best mean reward: 37.41 - Last mean reward per episode: 37.41
# Num timesteps: 4100
# Best mean reward: 37.41 - Last mean reward per episode: 37.41
# Num timesteps: 4120
# Best mean reward: 37.41 - Last mean reward per episode: 37.41
# Num timesteps: 4140
# Best mean reward: 37.41 - Last mean reward per episode: 37.41
# Num timesteps: 4160
# Best mean reward: 37.41 - Last mean reward per episode: 38.22
# Saving new best model at 4146 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4180
# Best mean reward: 38.22 - Last mean reward per episode: 38.22
# Num timesteps: 4200
# Best mean reward: 38.22 - Last mean reward per episode: 38.22
# Num timesteps: 4220
# Best mean reward: 38.22 - Last mean reward per episode: 38.22
# Num timesteps: 4240
# Best mean reward: 38.22 - Last mean reward per episode: 38.22
# Num timesteps: 4260
# Best mean reward: 38.22 - Last mean reward per episode: 39.08
# Saving new best model at 4242 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4280
# Best mean reward: 39.08 - Last mean reward per episode: 39.08
# Num timesteps: 4300
# Best mean reward: 39.08 - Last mean reward per episode: 39.08
# Num timesteps: 4320
# Best mean reward: 39.08 - Last mean reward per episode: 39.08
# Num timesteps: 4340
# Best mean reward: 39.08 - Last mean reward per episode: 39.73
# Saving new best model at 4332 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4360
# Best mean reward: 39.73 - Last mean reward per episode: 39.73
# Num timesteps: 4380
# Best mean reward: 39.73 - Last mean reward per episode: 39.73
# Num timesteps: 4400
# Best mean reward: 39.73 - Last mean reward per episode: 39.73
# Num timesteps: 4420
# Best mean reward: 39.73 - Last mean reward per episode: 39.73
# Num timesteps: 4440
# Best mean reward: 39.73 - Last mean reward per episode: 40.38
# Saving new best model at 4439 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4460
# Best mean reward: 40.38 - Last mean reward per episode: 40.38
# Num timesteps: 4480
# Best mean reward: 40.38 - Last mean reward per episode: 40.38
# Num timesteps: 4500
# Best mean reward: 40.38 - Last mean reward per episode: 40.38
# Num timesteps: 4520
# Best mean reward: 40.38 - Last mean reward per episode: 40.38
# Num timesteps: 4540
# Best mean reward: 40.38 - Last mean reward per episode: 40.83
# Saving new best model at 4525 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4560
# Best mean reward: 40.83 - Last mean reward per episode: 40.83
# Num timesteps: 4580
# Best mean reward: 40.83 - Last mean reward per episode: 40.83
# Num timesteps: 4600
# Best mean reward: 40.83 - Last mean reward per episode: 40.83
# Num timesteps: 4620
# Best mean reward: 40.83 - Last mean reward per episode: 40.83
# Num timesteps: 4640
# Best mean reward: 40.83 - Last mean reward per episode: 41.88
# Saving new best model at 4639 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4660
# Best mean reward: 41.88 - Last mean reward per episode: 41.88
# Num timesteps: 4680
# Best mean reward: 41.88 - Last mean reward per episode: 41.88
# Num timesteps: 4700
# Best mean reward: 41.88 - Last mean reward per episode: 41.88
# Num timesteps: 4720
# Best mean reward: 41.88 - Last mean reward per episode: 41.88
# Num timesteps: 4740
# Best mean reward: 41.88 - Last mean reward per episode: 42.65
# Saving new best model at 4732 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4760
# Best mean reward: 42.65 - Last mean reward per episode: 42.65
# Num timesteps: 4780
# Best mean reward: 42.65 - Last mean reward per episode: 42.65
# Num timesteps: 4800
# Best mean reward: 42.65 - Last mean reward per episode: 42.98
# Saving new best model at 4788 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4820
# Best mean reward: 42.98 - Last mean reward per episode: 42.98
# Num timesteps: 4840
# Best mean reward: 42.98 - Last mean reward per episode: 42.98
# Num timesteps: 4860
# Best mean reward: 42.98 - Last mean reward per episode: 42.98
# Num timesteps: 4880
# Best mean reward: 42.98 - Last mean reward per episode: 42.98
# Num timesteps: 4900
# Best mean reward: 42.98 - Last mean reward per episode: 42.98
# Num timesteps: 4920
# Best mean reward: 42.98 - Last mean reward per episode: 44.04
# Saving new best model at 4903 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4940
# Best mean reward: 44.04 - Last mean reward per episode: 44.13
# Saving new best model at 4925 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4960
# Best mean reward: 44.13 - Last mean reward per episode: 44.13
# Num timesteps: 4980
# Best mean reward: 44.13 - Last mean reward per episode: 44.13
# Num timesteps: 5000
# Best mean reward: 44.13 - Last mean reward per episode: 44.13
# Num timesteps: 5020
# Best mean reward: 44.13 - Last mean reward per episode: 44.13
# Num timesteps: 5040
# Best mean reward: 44.13 - Last mean reward per episode: 44.94
# Saving new best model at 5037 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5060
# Best mean reward: 44.94 - Last mean reward per episode: 44.94
# Num timesteps: 5080
# Best mean reward: 44.94 - Last mean reward per episode: 44.94
# Num timesteps: 5100
# Best mean reward: 44.94 - Last mean reward per episode: 44.94
# Num timesteps: 5120
# Best mean reward: 44.94 - Last mean reward per episode: 44.94
# Num timesteps: 5140
# Best mean reward: 44.94 - Last mean reward per episode: 44.94
# Num timesteps: 5160
# Best mean reward: 44.94 - Last mean reward per episode: 44.94
# Num timesteps: 5180
# Best mean reward: 44.94 - Last mean reward per episode: 44.94
# Num timesteps: 5200
# Best mean reward: 44.94 - Last mean reward per episode: 46.24
# Saving new best model at 5183 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5220
# Best mean reward: 46.24 - Last mean reward per episode: 46.24
# Num timesteps: 5240
# Best mean reward: 46.24 - Last mean reward per episode: 46.24
# Num timesteps: 5260
# Best mean reward: 46.24 - Last mean reward per episode: 46.24
# Num timesteps: 5280
# Best mean reward: 46.24 - Last mean reward per episode: 46.24
# Num timesteps: 5300
# Best mean reward: 46.24 - Last mean reward per episode: 46.24
# Num timesteps: 5320
# Best mean reward: 46.24 - Last mean reward per episode: 46.24
# Num timesteps: 5340
# Best mean reward: 46.24 - Last mean reward per episode: 46.24
# Num timesteps: 5360
# Best mean reward: 46.24 - Last mean reward per episode: 47.66
# Saving new best model at 5343 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5380
# Best mean reward: 47.66 - Last mean reward per episode: 47.66
# Num timesteps: 5400
# Best mean reward: 47.66 - Last mean reward per episode: 47.66
# Num timesteps: 5420
# Best mean reward: 47.66 - Last mean reward per episode: 47.66
# Num timesteps: 5440
# Best mean reward: 47.66 - Last mean reward per episode: 47.66
# Num timesteps: 5460
# Best mean reward: 47.66 - Last mean reward per episode: 47.66
# Num timesteps: 5480
# Best mean reward: 47.66 - Last mean reward per episode: 47.66
# Num timesteps: 5500
# Best mean reward: 47.66 - Last mean reward per episode: 47.66
# Num timesteps: 5520
# Best mean reward: 47.66 - Last mean reward per episode: 49.12
# Saving new best model at 5510 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5540
# Best mean reward: 49.12 - Last mean reward per episode: 49.12
# Num timesteps: 5560
# Best mean reward: 49.12 - Last mean reward per episode: 49.12
# Num timesteps: 5580
# Best mean reward: 49.12 - Last mean reward per episode: 49.43
# Saving new best model at 5564 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5600
# Best mean reward: 49.43 - Last mean reward per episode: 49.43
# Num timesteps: 5620
# Best mean reward: 49.43 - Last mean reward per episode: 49.43
# Num timesteps: 5640
# Best mean reward: 49.43 - Last mean reward per episode: 49.43
# Num timesteps: 5660
# Best mean reward: 49.43 - Last mean reward per episode: 49.43
# Num timesteps: 5680
# Best mean reward: 49.43 - Last mean reward per episode: 49.43
# Num timesteps: 5700
# Best mean reward: 49.43 - Last mean reward per episode: 50.41
# Saving new best model at 5681 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5720
# Best mean reward: 50.41 - Last mean reward per episode: 50.41
# Num timesteps: 5740
# Best mean reward: 50.41 - Last mean reward per episode: 50.41
# Num timesteps: 5760
# Best mean reward: 50.41 - Last mean reward per episode: 50.41
# Num timesteps: 5780
# Best mean reward: 50.41 - Last mean reward per episode: 50.41
# Num timesteps: 5800
# Best mean reward: 50.41 - Last mean reward per episode: 51.34
# Saving new best model at 5789 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5820
# Best mean reward: 51.34 - Last mean reward per episode: 51.34
# Num timesteps: 5840
# Best mean reward: 51.34 - Last mean reward per episode: 51.34
# Num timesteps: 5860
# Best mean reward: 51.34 - Last mean reward per episode: 51.34
# Num timesteps: 5880
# Best mean reward: 51.34 - Last mean reward per episode: 52.12
# Saving new best model at 5879 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5900
# Best mean reward: 52.12 - Last mean reward per episode: 52.12
# Num timesteps: 5920
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 5940
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 5960
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 5980
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 6000
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 6020
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 6040
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 6060
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 6080
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 6100
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 6120
# Best mean reward: 52.12 - Last mean reward per episode: 52.11
# Num timesteps: 6140
# Best mean reward: 52.12 - Last mean reward per episode: 53.85
# Saving new best model at 6130 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6160
# Best mean reward: 53.85 - Last mean reward per episode: 53.85
# Num timesteps: 6180
# Best mean reward: 53.85 - Last mean reward per episode: 53.85
# Num timesteps: 6200
# Best mean reward: 53.85 - Last mean reward per episode: 54.12
# Saving new best model at 6193 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6220
# Best mean reward: 54.12 - Last mean reward per episode: 54.12
# Num timesteps: 6240
# Best mean reward: 54.12 - Last mean reward per episode: 54.12
# Num timesteps: 6260
# Best mean reward: 54.12 - Last mean reward per episode: 54.12
# Num timesteps: 6280
# Best mean reward: 54.12 - Last mean reward per episode: 54.12
# Num timesteps: 6300
# Best mean reward: 54.12 - Last mean reward per episode: 54.86
# Saving new best model at 6298 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6320
# Best mean reward: 54.86 - Last mean reward per episode: 54.86
# Num timesteps: 6340
# Best mean reward: 54.86 - Last mean reward per episode: 54.86
# Num timesteps: 6360
# Best mean reward: 54.86 - Last mean reward per episode: 54.86
# Num timesteps: 6380
# Best mean reward: 54.86 - Last mean reward per episode: 54.86
# Num timesteps: 6400
# Best mean reward: 54.86 - Last mean reward per episode: 54.86
# Num timesteps: 6420
# Best mean reward: 54.86 - Last mean reward per episode: 54.86
# Num timesteps: 6440
# Best mean reward: 54.86 - Last mean reward per episode: 54.86
# Num timesteps: 6460
# Best mean reward: 54.86 - Last mean reward per episode: 54.86
# Num timesteps: 6480
# Best mean reward: 54.86 - Last mean reward per episode: 56.35
# Saving new best model at 6463 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6500
# Best mean reward: 56.35 - Last mean reward per episode: 56.35
# Num timesteps: 6520
# Best mean reward: 56.35 - Last mean reward per episode: 56.35
# Num timesteps: 6540
# Best mean reward: 56.35 - Last mean reward per episode: 56.68
# Saving new best model at 6523 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6560
# Best mean reward: 56.68 - Last mean reward per episode: 56.68
# Num timesteps: 6580
# Best mean reward: 56.68 - Last mean reward per episode: 56.68
# Num timesteps: 6600
# Best mean reward: 56.68 - Last mean reward per episode: 56.68
# Num timesteps: 6620
# Best mean reward: 56.68 - Last mean reward per episode: 56.68
# Num timesteps: 6640
# Best mean reward: 56.68 - Last mean reward per episode: 56.68
# Num timesteps: 6660
# Best mean reward: 56.68 - Last mean reward per episode: 57.20
# Saving new best model at 6660 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6680
# Best mean reward: 57.20 - Last mean reward per episode: 57.20
# Num timesteps: 6700
# Best mean reward: 57.20 - Last mean reward per episode: 57.20
# Num timesteps: 6720
# Best mean reward: 57.20 - Last mean reward per episode: 57.20
# Num timesteps: 6740
# Best mean reward: 57.20 - Last mean reward per episode: 57.20
# Num timesteps: 6760
# Best mean reward: 57.20 - Last mean reward per episode: 57.20
# Num timesteps: 6780
# Best mean reward: 57.20 - Last mean reward per episode: 58.05
# Saving new best model at 6765 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6800
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 6820
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 6840
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 6860
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 6880
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 6900
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 6920
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 6940
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 6960
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 6980
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 7000
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 7020
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 7040
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 7060
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 7080
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 7100
# Best mean reward: 58.05 - Last mean reward per episode: 58.05
# Num timesteps: 7120
# Best mean reward: 58.05 - Last mean reward per episode: 61.19
# Saving new best model at 7101 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7140
# Best mean reward: 61.19 - Last mean reward per episode: 61.19
# Num timesteps: 7160
# Best mean reward: 61.19 - Last mean reward per episode: 61.19
# Num timesteps: 7180
# Best mean reward: 61.19 - Last mean reward per episode: 61.19
# Num timesteps: 7200
# Best mean reward: 61.19 - Last mean reward per episode: 61.19
# Num timesteps: 7220
# Best mean reward: 61.19 - Last mean reward per episode: 61.95
# Saving new best model at 7201 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7240
# Best mean reward: 61.95 - Last mean reward per episode: 61.95
# Num timesteps: 7260
# Best mean reward: 61.95 - Last mean reward per episode: 61.95
# Num timesteps: 7280
# Best mean reward: 61.95 - Last mean reward per episode: 62.39
# Saving new best model at 7265 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7300
# Best mean reward: 62.39 - Last mean reward per episode: 62.39
# Num timesteps: 7320
# Best mean reward: 62.39 - Last mean reward per episode: 62.38
# Num timesteps: 7340
# Best mean reward: 62.39 - Last mean reward per episode: 62.38
# Num timesteps: 7360
# Best mean reward: 62.39 - Last mean reward per episode: 62.38
# Num timesteps: 7380
# Best mean reward: 62.39 - Last mean reward per episode: 62.92
# Saving new best model at 7373 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7400
# Best mean reward: 62.92 - Last mean reward per episode: 62.92
# Num timesteps: 7420
# Best mean reward: 62.92 - Last mean reward per episode: 62.92
# Num timesteps: 7440
# Best mean reward: 62.92 - Last mean reward per episode: 62.92
# Num timesteps: 7460
# Best mean reward: 62.92 - Last mean reward per episode: 63.44
# Saving new best model at 7443 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7480
# Best mean reward: 63.44 - Last mean reward per episode: 63.44
# Num timesteps: 7500
# Best mean reward: 63.44 - Last mean reward per episode: 63.44
# Num timesteps: 7520
# Best mean reward: 63.44 - Last mean reward per episode: 63.44
# Num timesteps: 7540
# Best mean reward: 63.44 - Last mean reward per episode: 63.44
# Num timesteps: 7560
# Best mean reward: 63.44 - Last mean reward per episode: 63.44
# Num timesteps: 7580
# Best mean reward: 63.44 - Last mean reward per episode: 64.54
# Saving new best model at 7567 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7600
# Best mean reward: 64.54 - Last mean reward per episode: 64.54
# Num timesteps: 7620
# Best mean reward: 64.54 - Last mean reward per episode: 64.54
# Num timesteps: 7640
# Best mean reward: 64.54 - Last mean reward per episode: 64.54
# Num timesteps: 7660
# Best mean reward: 64.54 - Last mean reward per episode: 65.19
# Saving new best model at 7647 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7680
# Best mean reward: 65.19 - Last mean reward per episode: 65.19
# Num timesteps: 7700
# Best mean reward: 65.19 - Last mean reward per episode: 65.19
# Num timesteps: 7720
# Best mean reward: 65.19 - Last mean reward per episode: 65.19
# Num timesteps: 7740
# Best mean reward: 65.19 - Last mean reward per episode: 65.19
# Num timesteps: 7760
# Best mean reward: 65.19 - Last mean reward per episode: 65.19
# Num timesteps: 7780
# Best mean reward: 65.19 - Last mean reward per episode: 65.19
# Num timesteps: 7800
# Best mean reward: 65.19 - Last mean reward per episode: 66.48
# Saving new best model at 7787 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7820
# Best mean reward: 66.48 - Last mean reward per episode: 66.48
# Num timesteps: 7840
# Best mean reward: 66.48 - Last mean reward per episode: 66.48
# Num timesteps: 7860
# Best mean reward: 66.48 - Last mean reward per episode: 66.48
# Num timesteps: 7880
# Best mean reward: 66.48 - Last mean reward per episode: 66.48
# Num timesteps: 7900
# Best mean reward: 66.48 - Last mean reward per episode: 66.48
# Num timesteps: 7920
# Best mean reward: 66.48 - Last mean reward per episode: 67.48
# Saving new best model at 7903 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7940
# Best mean reward: 67.48 - Last mean reward per episode: 67.48
# Num timesteps: 7960
# Best mean reward: 67.48 - Last mean reward per episode: 67.48
# Num timesteps: 7980
# Best mean reward: 67.48 - Last mean reward per episode: 67.48
# Num timesteps: 8000
# Best mean reward: 67.48 - Last mean reward per episode: 67.48
# Num timesteps: 8020
# Best mean reward: 67.48 - Last mean reward per episode: 67.48
# Num timesteps: 8040
# Best mean reward: 67.48 - Last mean reward per episode: 67.48
# Num timesteps: 8060
# Best mean reward: 67.48 - Last mean reward per episode: 67.48
# Num timesteps: 8080
# Best mean reward: 67.48 - Last mean reward per episode: 67.48
# Num timesteps: 8100
# Best mean reward: 67.48 - Last mean reward per episode: 69.19
# Saving new best model at 8088 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 8120
# Best mean reward: 69.19 - Last mean reward per episode: 69.19
# Num timesteps: 8140
# Best mean reward: 69.19 - Last mean reward per episode: 69.19
# Num timesteps: 8160
# Best mean reward: 69.19 - Last mean reward per episode: 69.19
# Num timesteps: 8180
# Best mean reward: 69.19 - Last mean reward per episode: 69.19
# Num timesteps: 8200
# Best mean reward: 69.19 - Last mean reward per episode: 69.19
# Num timesteps: 8220
# Best mean reward: 69.19 - Last mean reward per episode: 70.32
# Saving new best model at 8214 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 8240
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8260
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8280
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8300
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8320
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8340
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8360
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8380
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8400
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8420
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8440
# Best mean reward: 70.32 - Last mean reward per episode: 70.32
# Num timesteps: 8460
# Best mean reward: 70.32 - Last mean reward per episode: 72.46
# Saving new best model at 8447 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 8480
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8500
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8520
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8540
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8560
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8580
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8600
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8620
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8640
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8660
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8680
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8700
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8720
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8740
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8760
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8780
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8800
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8820
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8840
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8860
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8880
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8900
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8920
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8940
# Best mean reward: 72.46 - Last mean reward per episode: 72.46
# Num timesteps: 8960
# Best mean reward: 72.46 - Last mean reward per episode: 77.25
# Saving new best model at 8947 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 8980
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9000
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9020
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9040
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9060
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9080
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9100
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9120
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9140
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9160
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9180
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9200
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9220
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9240
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9260
# Best mean reward: 77.25 - Last mean reward per episode: 77.25
# Num timesteps: 9280
# Best mean reward: 77.25 - Last mean reward per episode: 80.31
# Saving new best model at 9273 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 9300
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9320
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9340
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9360
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9380
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9400
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9420
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9440
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9460
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9480
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9500
# Best mean reward: 80.31 - Last mean reward per episode: 80.31
# Num timesteps: 9520
# Best mean reward: 80.31 - Last mean reward per episode: 82.42
# Saving new best model at 9514 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 9540
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9560
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9580
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9600
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9620
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9640
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9660
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9680
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9700
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9720
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9740
# Best mean reward: 82.42 - Last mean reward per episode: 82.42
# Num timesteps: 9760
# Best mean reward: 82.42 - Last mean reward per episode: 84.55
# Saving new best model at 9742 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 9780
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 9800
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 9820
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 9840
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 9860
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 9880
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 9900
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 9920
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 9940
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 9960
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 9980
# Best mean reward: 84.55 - Last mean reward per episode: 84.55
# Num timesteps: 10000
# Best mean reward: 84.55 - Last mean reward per episode: 84.55

# %% [markdown]
# ## Second example: Realtime plotting of performance
# While training, it is sometimes useful to how the training progresses over time, relative to the episodic reward.
# For this, Stable-Baselines has [Tensorboard support](https://stable-baselines.readthedocs.io/en/master/guide/tensorboard.html), however this can be very combersome, especially in disk space usage.
#
# **NOTE: Unfortunately live plotting does not work out of the box on google colab**
#
# Here, we can use callback again, to plot the episodic reward in realtime, using the monitoring wrapper:

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
# %matplotlib inline
# %matplotlib qt

class PlottingCallback(BaseCallback):
    """
    Callback for plotting the performance in realtime.

    :param verbose: (int)
    """
    def __init__(self, verbose=1):
        super(PlottingCallback, self).__init__(verbose)
        self._plot = None

    def _on_step(self) -> bool:
        # get the monitor's data
        x, y = ts2xy(load_results(log_dir), 'timesteps')
        if self._plot is None: # make the plot
            plt.ion()
            fig = plt.figure(figsize=(6,3))
            ax = fig.add_subplot(111)
            line, = ax.plot(x, y)
            self._plot = (line, ax, fig)
            plt.show()
        else: # update and rescale the plot
            self._plot[0].set_data(x, y)
            self._plot[-2].relim()
            self._plot[-2].set_xlim([self.locals["total_timesteps"] * -0.02, 
                                    self.locals["total_timesteps"] * 1.02])
            self._plot[-2].autoscale_view(True,True,True)
            self._plot[-1].canvas.draw()
        
# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env('MountainCarContinuous-v0', n_envs=1, monitor_dir=log_dir)

plotting_callback = PlottingCallback()
        
model = PPO('MlpPolicy', env, verbose=0)
model.learn(20_000, callback=plotting_callback)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1113857/2583653479.py in <module>
#      43
#      44 model = PPO('MlpPolicy', env, verbose=0)
# ---> 45 model.learn(10, callback=plotting_callback)
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     305     ) -> SelfPPO:
#     306
# --> 307         return super().learn(
#     308             total_timesteps=total_timesteps,
#     309             callback=callback,
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     246         while self.num_timesteps < total_timesteps:
#     247
# --> 248             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     249
#     250             if continue_training is False:
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     179             # Give access to local variables
#     180             callback.update_locals(locals())
# --> 181             if callback.on_step() is False:
#     182                 return False
#     183
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/callbacks.py in on_step(self)
#      98         self.num_timesteps = self.model.num_timesteps
#      99
# --> 100         return self._on_step()
#     101
#     102     def on_training_end(self) -> None:
#
# /tmp/ipykernel_1113857/2583653479.py in _on_step(self)
#      17     def _on_step(self) -> bool:
#      18         # get the monitor's data
# ---> 19         x, y = ts2xy(load_results(log_dir), 'timesteps')
#      20         if self._plot is None: # make the plot
#      21             plt.ion()
#
# ~/.local/lib/python3.8/site-packages/stable_baselines3/common/monitor.py in load_results(path)
#     251     data_frame.sort_values("t", inplace=True)
#     252     data_frame.reset_index(inplace=True)
# --> 253     data_frame["t"] -= min(header["t_start"] for header in headers)
#     254     return data_frame
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3485         else:
#    3486             # set column
# -> 3487             self._set_item(key, value)
#    3488
#    3489     def _setitem_slice(self, key, value):
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3561         """
#    3562
# -> 3563         self._ensure_valid_index(value)
#    3564         value = self._sanitize_column(key, value)
#    3565         NDFrame._set_item(self, key, value)
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    3546                 )
#    3547
# -> 3548             self._data = self._data.reindex_axis(
#    3549                 value.index.copy(), axis=1, fill_value=np.nan
#    3550             )
#
# /usr/lib/python3/dist-packages/pandas/core/internals/managers.py in reindex_axis(self, new_index, axis, method, limit, fill_value, copy)
#    1218         )
#    1219
# -> 1220         return self.reindex_indexer(
#    1221             new_index, indexer, axis=axis, fill_value=fill_value, copy=copy
#    1222         )
#
# /usr/lib/python3/dist-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1240                 return self
#    1241
# -> 1242             result = self.copy(deep=copy)
#    1243             result.axes = list(self.axes)
#    1244             result.axes[axis] = new_axis
#
# /usr/lib/python3/dist-packages/pandas/core/internals/managers.py in copy(self, deep)
#     783             else:
#     784                 copy = lambda ax: ax.view()
# --> 785             new_axes = [copy(ax) for ax in self.axes]
#     786         else:
#     787             new_axes = list(self.axes)
#
# /usr/lib/python3/dist-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     783             else:
#     784                 copy = lambda ax: ax.view()
# --> 785             new_axes = [copy(ax) for ax in self.axes]
#     786         else:
#     787             new_axes = list(self.axes)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Third example: Progress bar
# Quality of life improvement are always welcome when developping and using RL. Here, we used [tqdm](https://tqdm.github.io/) to show a progress bar of the training, along with number of timesteps per second and the estimated time remaining to the end of the training:

# %%
from tqdm.auto import tqdm

class ProgressBarCallback(BaseCallback):
    """
    :param pbar: (tqdm.pbar) Progress bar object
    """
    def __init__(self, pbar):
        super(ProgressBarCallback, self).__init__()
        self._pbar = pbar

    def _on_step(self):
        # Update the progress bar:
        self._pbar.n = self.num_timesteps
        self._pbar.update(0)

# this callback uses the 'with' block, allowing for correct initialisation and destruction
class ProgressBarManager(object):
    def __init__(self, total_timesteps): # init object with total timesteps
        self.pbar = None
        self.total_timesteps = total_timesteps
        
    def __enter__(self): # create the progress bar and callback, return the callback
        self.pbar = tqdm(total=self.total_timesteps)
            
        return ProgressBarCallback(self.pbar)

    def __exit__(self, exc_type, exc_val, exc_tb): # close the callback
        self.pbar.n = self.total_timesteps
        self.pbar.update(0)
        self.pbar.close()
        
model = TD3('MlpPolicy', 'Pendulum-v1', verbose=0)
with ProgressBarManager(2000) as callback: # this the garanties that the tqdm progress bar closes correctly
    model.learn(2000, callback=callback)
# Out:
# 100%|██████████| 2000/2000 [00:04<00:00, 462.87it/s]

# %% [markdown]
# ## Forth example: Composition
# Thanks to the functional nature of callbacks, it is possible to do a composition of callbacks, into a single callback. This means we can auto save our best model, show the progess bar and episodic reward of the training.
#
# The callbacks are automatically composed when you pass a list to the `learn()` method. Under the hood, a `CallbackList` is created.

# %%
from stable_baselines3.common.callbacks import CallbackList

# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = make_vec_env('CartPole-v1', n_envs=1, monitor_dir=log_dir)

# Create callbacks
auto_save_callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)

model = PPO('MlpPolicy', env, verbose=0)
with ProgressBarManager(10000) as progress_callback:
  # This is equivalent to callback=CallbackList([progress_callback, auto_save_callback])
  model.learn(10000, callback=[progress_callback, auto_save_callback])
# Out:
#  15%|█▍        | 1460/10000 [00:00<00:03, 2416.78it/s]
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: 20.71
# Saving new best model at 994 timesteps
# Saving new best model to /tmp/gym/best_model.zip
#  19%|█▉        | 1928/10000 [00:00<00:03, 2372.70it/s]
# Num timesteps: 2000
# Best mean reward: 20.71 - Last mean reward per episode: 20.69
#  34%|███▎      | 3350/10000 [00:01<00:03, 1818.63it/s]
# Num timesteps: 3000
# Best mean reward: 20.71 - Last mean reward per episode: 22.76
# Saving new best model at 2998 timesteps
# Saving new best model to /tmp/gym/best_model.zip
#  41%|████      | 4055/10000 [00:02<00:02, 2118.12it/s]
# Num timesteps: 4000
# Best mean reward: 22.76 - Last mean reward per episode: 26.19
# Saving new best model at 3980 timesteps
# Saving new best model to /tmp/gym/best_model.zip
#  52%|█████▏    | 5249/10000 [00:03<00:02, 1639.45it/s]
# Num timesteps: 5000
# Best mean reward: 26.19 - Last mean reward per episode: 31.44
# Saving new best model at 4993 timesteps
# Saving new best model to /tmp/gym/best_model.zip
#  60%|█████▉    | 5956/10000 [00:03<00:01, 2053.77it/s]
# Num timesteps: 6000
# Best mean reward: 31.44 - Last mean reward per episode: 34.56
# Saving new best model at 5996 timesteps
# Saving new best model to /tmp/gym/best_model.zip
#  74%|███████▍  | 7379/10000 [00:04<00:01, 1783.36it/s]
# Num timesteps: 7000
# Best mean reward: 34.56 - Last mean reward per episode: 39.36
# Saving new best model at 6973 timesteps
# Saving new best model to /tmp/gym/best_model.zip
#  81%|████████  | 8083/10000 [00:05<00:00, 2097.05it/s]
# Num timesteps: 8000
# Best mean reward: 39.36 - Last mean reward per episode: 44.37
# Saving new best model at 7928 timesteps
# Saving new best model to /tmp/gym/best_model.zip
#  93%|█████████▎| 9277/10000 [00:06<00:00, 1624.07it/s]
# Num timesteps: 9000
# Best mean reward: 44.37 - Last mean reward per episode: 49.43
# Saving new best model at 8867 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# 10234it [00:06, 2132.71it/s]
# Num timesteps: 10000
# Best mean reward: 49.43 - Last mean reward per episode: 56.36
# Saving new best model at 9957 timesteps
# Saving new best model to /tmp/gym/best_model.zip
# 100%|██████████| 10000/10000 [00:07<00:00, 1374.84it/s]

# %% [markdown]
# ## Exercise: Code your own callback
#
#
# The previous examples showed the basics of what is a callback and what you do with it.
#
# The goal of this exercise is to create a callback that will evaluate the model using a test environment and save it if this is the best known model.
#
# To make things easier, we are going to use a class instead of a function with the magic method `__call__`.

# %%
class EvalCallback(BaseCallback):
  """
  Callback for evaluating an agent.
  
  :param eval_env: (gym.Env) The environment used for initialization
  :param n_eval_episodes: (int) The number of episodes to test the agent
  :param eval_freq: (int) Evaluate the agent every eval_freq call of the callback.
  """
  def __init__(self, eval_env, n_eval_episodes=5, eval_freq=20):
    super(EvalCallback, self).__init__()
    self.eval_env = eval_env
    self.n_eval_episodes = n_eval_episodes
    self.eval_freq = eval_freq
    self.best_mean_reward = -np.inf
  
  def _on_step(self):
    """
    This method will be called by the model.

    :return: (bool)
    """
    
    # self.n_calls is automatically updated because
    # we derive from BaseCallback
    if self.n_calls % self.eval_freq == 0:
      # === YOUR CODE HERE ===#
      # Evaluate the agent:
      # you need to do self.n_eval_episodes loop using self.eval_env
      # hint: you can use self.model.predict(obs, deterministic=True)
      
      # Save the agent if needed
      # and update self.best_mean_reward
      
      print("Best mean reward: {:.2f}".format(self.best_mean_reward))
      

      # ====================== #    
    return True

# %% [markdown]
# ### Test your callback

# %%
# Env used for training
env = gym.make("CartPole-v1")
# Env for evaluating the agent
eval_env gym.make("CartPole-v1")

# === YOUR CODE HERE ===#
# Create the callback object
callback = None

# Create the RL model
model = None

# ====================== #

# Train the RL model
model.learn(int(100000), callback=callback)

# %% [markdown]
# # Conclusion
#
#
# In this notebook we have seen:
# - that good hyperparameters are key to the success of RL, you should not except the default ones to work on every problems
# - what is a callback and what you can do with it
# - how to create your own callback
